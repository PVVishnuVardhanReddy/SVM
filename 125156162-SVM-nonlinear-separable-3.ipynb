# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=500, noise=0.3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
svm_model = SVC(kernel='rbf', C=1, gamma='scale')
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# %%
sns.heatmap(conf_matrix, annot=True)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91        75
#            1       0.98      0.83      0.90        75
#
#     accuracy                           0.91       150
#    macro avg       0.92      0.91      0.91       150
# weighted avg       0.92      0.91      0.91       150

# %%
plt.figure(figsize=(12, 5))
h = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svm_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap='Blues', alpha=0.3)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='Set1', edgecolor='k', s=75)
plt.title('SVM Decision Boundary and Regions(RBF-kernel)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
svm_model = SVC(kernel='poly', C=1, gamma='scale')
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True)
print("Classification Report:\n", class_report)
plt.figure(figsize=(12, 5))
h = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svm_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap='Blues', alpha=0.3)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='Set1', edgecolor='k', s=75)
plt.title('SVM Decision Boundary and Regions(Polynomial-kernel)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84        75
#            1       0.89      0.76      0.82        75
#
#     accuracy                           0.83       150
#    macro avg       0.84      0.83      0.83       150
# weighted avg       0.84      0.83      0.83       150

# %%
svm_model = SVC(kernel='sigmoid', C=1, gamma='scale')
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True)
print("Classification Report:\n", class_report)
plt.figure(figsize=(12, 5))
h = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = svm_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap='Blues', alpha=0.3)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='Set1', edgecolor='k', s=75)
plt.title('SVM Decision Boundary and Regions(sigmoid-kernel)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62        75
#            1       0.62      0.59      0.60        75
#
#     accuracy                           0.61       150
#    macro avg       0.61      0.61      0.61       150
# weighted avg       0.61      0.61      0.61       150
